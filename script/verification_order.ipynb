# %% [markdown]
# # Verification

# %% [markdown]
# Small program to check the existence of files referenced in the directory and sort it according to the type of documents. <br>
# *Bonus* : hand count and select documents for model HTR

# %% [markdown]
# ## Import

# %%
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import random, os, shutil

current_folder = os.path.abspath('')

# %% [markdown]
# ## Check csv

# %%
#import csv
df = pd.read_csv('data/araucania_prepared.csv', delimiter=",")

df.tail(n=50)
# Out:
#     Box    Id               Type  \
# 204   4   354            Letters
# 205   4   355            Letters
# 206   4   356            Letters
# 207   4   357            Letters
# 208   4   358            Letters
# 209   4   359            Letters
# 210   4   360            Letters
# 211   4   361            Letters
# 212   4   362            Letters
# 213   4   363            Letters
# 214   4   364            Letters
# 215   4   365            Letters
# 216   4   366            Letters
# 217   4   367            Letters
# 218   4   368            Letters
# 219   4   369            Letters
# 220   4   370            Letters
# 221   4   371            Letters
# 222   4   372            Letters
# 223   4   373            Letters
# 224   4   374            Letters
# 225   4   375             Oficio
# 226   4   376             Oficio
# 227   4   377             Oficio
# 228   4   378             Oficio
# 229   4   379             Oficio
# 230   4   380            Letters
# 231   4   381            Letters
# 232   4   382            Letters
# 233   4   383            Letters
# 234   4   384            Letters
# 235   4   385            Letters
# 236   4   386            Letters
# 237   4   387            Letters
# 238   4   388            Letters
# 239   4   389              Notes
# 240   4   390            Letters
# 241  4A   391             Others
# 242   4   392             Others
# 243   4   393            Letters
# 244   4   394             Others
# 245   4   395             Report
# 246   4   396             Others
# 247   4   397             Report
# 248  4A   398                Map
# 249  4A   399                Map
# 250   4   887  Archives (series)
# 251   4   888  Archives (series)
# 252  61  1643               Book
# 253  62  1677            Letters
#
#                                                  Title  \
# 204  Carta del 30 de octubre de 1860 de Vicente Vil...
# 205  Carta del 30 de octubre de 1860 de Vicente Vil...
# 206  Carta del 30 de octubre de 1860 de Vicente Pér...
# 207  Carta del 30 de octubre de 1860 de Vicente Pér...
# 208  Carta del 31 de octubre de 1860 de Vicente Vil...
# 209  Carta del 01 de noviembre de 1860 de Manuel Se...
# 210  Carta del 02 de noviembre de 1860 de José Marí...
# 211  Carta del 04 de noviembre de 1860 de José Marí...
# 212  Carta del 08 de noviembre de 1860 de José Anto...
# 213  Carta del 10 de noviembre de 1860 de Vicente V...
# 214  Carta del 10 de noviembre de 1860 de Vicente V...
# 215  Carta del 10 de noviembre de 1860 de José Sepú...
# 216  Carta del 12 de noviembre de 1860 de Vicente V...
# 217  Carta del 17 de noviembre de 1860 de Vicente P...
# 218  Carta del 21 de noviembre de 1860 de Francisco...
# 219  Carta del 22 de noviembre de 1860 de Vicente V...
# 220  Carta del 22 de noviembre de 1860 de Vicente V...
# 221  Carta del 23 de noviembre de 1860 al Comandant...
# 222  Carta del 23 de noviembre de 1860 de Vicente V...
# 223  Carta del 23 de noviembre de 1860 de Vicente V...
# 224  Carta del 28 de noviembre de 1860 de Juan Avel...
# 225  Oficio de Eleuterio Ramírez y respuesta al mis...
# 226  Oficio de Mauricio Barbosa a Eleuterio Ramírez...
# 227                         Oficio de Mauricio Barbosa
# 228  Oficio del Consejo de Guerra. Compuesto por J....
# 229  Oficio de J. Díaz al comandante de Armas de Ar...
# 230  Carta del 02 de marzo de 1860 de Nicolás Saave...
# 231  Carta del 02 de marzo de 1860 de J. A. Quezada...
# 232  Carta del 04 de marzo de 1860 de J. A. Quezada...
# 233  Carta del 02 de marzo de 1860 de Vicente Villa...
# 234    Carta del 04 de marzo de 1860 de J. Del C. Díaz
# 235  Carta del 13 de marzo de 1860 de Vicente Pérez...
# 236  Carta del 16 de marzo de 1860 de Vicente Villa...
# 237  Carta del 16 de marzo de 1860 de Manuel García...
# 238  Carta del 22 de marzo de 1860 de Manuel García...
# 239  Nota Nº 363 de Manuel García al Coronel Gradua...
# 240  Carta del 31 de marzo de 1860 de Juan Contrera...
# 241  Cuadro General del Ejército del Sur, Estado qu...
# 242                               Caciques de la costa
# 243  Carta en la cual Bernabé Chacón renuncia a su ...
# 244  Relación de los caciques que deben comparecer ...
# 245  Informe al Ministro de Guerra sobre una expedi...
# 246  Relación de cuarenta y ocho (48) legajos de co...
# 247  Informe sobre el estudio de la línea de fuerte...
# 248             Mapa de 31x44 cms.de la zona de Arauco
# 249  Mapa de 60x89 cms. de la Región de Arauco, mos...
# 250  Serie de documentos que dan cuenta de los serv...
# 251  Serie de documentos oficiales firmados por Bel...
# 252  Libro copiador de correspondencia del general ...
# 253  Carta del 27 de agosto de 1877 de Cornelio Saa...
#
#                         Author            Author2         Date  \
# 204          Villalón, Vicente                NaN   1860/10/30
# 205          Villalón, Vicente                NaN   1860/10/30
# 206     Pérez Rosales, Vicente                NaN   1860/10/30
# 207     Pérez Rosales, Vicente                NaN   1860/10/30
# 208          Villalón, Vicente                NaN   1860/10/31
# 209     Escala, Manuel Segundo                NaN   1860/11/01
# 210       Carrillo, José María                NaN   1860/11/02
# 211       Carrillo, José María                NaN   1860/11/04
# 212      Quezada, José Antonio                NaN   1860/11/08
# 213          Villalón, Vicente                NaN   1860/11/10
# 214          Villalón, Vicente                NaN   1860/11/10
# 215            Sepúlveda, José                NaN   1860/11/10
# 216          Villalón, Vicente                NaN   1860/11/12
# 217     Pérez Rosales, Vicente                NaN   1860/11/17
# 218         Río, Francisco Del                NaN   1860/11/21
# 219          Villalón, Vicente                NaN   1860/11/22
# 220          Villalón, Vicente                NaN   1860/11/22
# 221                        NaN                NaN   1860/11/23
# 222        Villalobos, Vicente                NaN   1860/11/23
# 223        Villalobos, Vicente                NaN   1860/11/23
# 224               Avello, Juan                NaN   1860/11/28
# 225         Ramírez, Eleuterio  Barbosa, Mauricio   1859/11/22
# 226          Barbosa, Mauricio                NaN   1859/11/22
# 227          Barbosa, Mauricio                NaN   1859/11/19
# 228          Consejo De Guerra                NaN   1859/12/28
# 229      Díaz, José Del Carmen                NaN   1859/12/25
# 230          Saavedra, Nicolás                NaN   1860/03/02
# 231      Quezada, José Antonio                NaN   1860/03/02
# 232      Quezada, José Antonio                NaN   1860/03/04
# 233        Villalobos, Vicente                NaN   1860/03/02
# 234      Díaz, José Del Carmen                NaN   1860/03/04
# 235     Pérez Rosales, Vicente                NaN   1860/03/13
# 236          Villalón, Vicente                NaN   1860/03/16
# 237             García, Manuel                NaN   1860/03/16
# 238             García, Manuel                NaN   1860/03/22
# 239             García, Manuel                NaN  [Siglo XIX]
# 240            Contreras, Juan                NaN   1860/03/31
# 241        Gómez Solar, Egidio      León, Juan De   1881/04/11
# 242                        NaN                NaN  [Siglo XIX]
# 243            Chacón, Bernabé                NaN  [Siglo XIX]
# 244    Fernández, Antonio José                NaN   1862/10/24
# 245                        NaN                NaN  [Siglo XIX]
# 246            Capitán Gacitúa                NaN   1905/12/12
# 247                        NaN                NaN   1884/11/14
# 248                        NaN                NaN  [Siglo XIX]
# 249                        NaN                NaN  [Siglo XIX]
# 250                        NaN                NaN    1862-1909
# 251                        NaN                NaN         1877
# 252  Urrutia Venegas, Gregorio                NaN   1866/05/04
# 253         Saavedra, Cornelio                NaN   1877/08/27
#
#                                 Location   Nb                     People  \
# 204      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 205      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 206       Chile;Octava Región;Concepción    1          Barbosa, Mauricio
# 207       Chile;Octava Región;Concepción    1          Barbosa, Mauricio
# 208      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 209       Chile;Octava Región;Concepción    1          Barbosa, Mauricio
# 210                     Chile;Guilañanen    1          Barbosa, Mauricio
# 211           Chile;Octava Región;Quiapo    1          Barbosa, Mauricio
# 212           Chile;Octava Región;Arauco    1          Barbosa, Mauricio
# 213      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 214      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 215       Chile;Octava Región;Nacimiento    1          Barbosa, Mauricio
# 216      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 217       Chile;Octava Región;Concepción    1          Barbosa, Mauricio
# 218           Chile;Octava Región;Arauco    1          Barbosa, Mauricio
# 219      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 220      Chile;Octava Región;Los Ángeles    1          Barbosa, Mauricio
# 221      Chile;Octava Región;Los Ángeles    1                        NaN
# 222      Chile;Octava Región;Los Ángeles    1                        NaN
# 223      Chile;Octava Región;Los Ángeles    2          Barbosa, Mauricio
# 224      Chile;Octava Región;Santa Juana    1                        NaN
# 225           Chile;Octava Región;Arauco    2                        NaN
# 226           Chile;Octava Región;Arauco    2         Ramírez, Eleuterio
# 227           Chile;Octava Región;Arauco    2                        NaN
# 228                        Chile;Paicaví    2                        NaN
# 229           Chile;Octava Región;Arauco    1                        NaN
# 230             Chile;Octava Región;Lebu    1          Barbosa, Mauricio
# 231           Chile;Octava Región;Arauco    1          Barbosa, Mauricio
# 232           Chile;Octava Región;Arauco    1          Barbosa, Mauricio
# 233      Chile;Octava Región;Los Ángeles    2          Barbosa, Mauricio
# 234           Chile;Octava Región;Arauco    2          Barbosa, Mauricio
# 235       Chile;Octava Región;Concepción    2          Barbosa, Mauricio
# 236          Chile;Octava Región;Ángeles    1          Barbosa, Mauricio
# 237  Chile;Región Metropolitana;Santiago    1          Barbosa, Mauricio
# 238  Chile;Región Metropolitana;Santiago    1          Barbosa, Mauricio
# 239                                  NaN    1          Barbosa, Mauricio
# 240           Chile;Octava Región;Arauco    1          Barbosa, Mauricio
# 241            Chile;Novena Región;Angol    1                        NaN
# 242                                  NaN    1                        NaN
# 243                                  NaN    1                        NaN
# 244          Chile;Octava Región;Negrete    1                        NaN
# 245                                  NaN   21                        NaN
# 246  Chile;Región Metropolitana;Santiago    2         Saavedra, Cornelio
# 247            Chile;Novena Región;Angol    6                        NaN
# 248                                  NaN    1                        NaN
# 249                                  NaN    1                        NaN
# 250                                  NaN   46                        NaN
# 251                                  NaN   54                        NaN
# 252             Chile;Octava Región;Lota  600                        NaN
# 253  Chile;Región Metropolitana;Santiago    1  Urrutia Venegas, Gregorio
#
#                                                Geo
# 204                                            NaN
# 205                                            NaN
# 206                                            NaN
# 207                                            NaN
# 208                                            NaN
# 209                                            NaN
# 210                                            NaN
# 211                                            NaN
# 212                                         Arauco
# 213                                            NaN
# 214                                            NaN
# 215                                            NaN
# 216                                            NaN
# 217                                            NaN
# 218                                         Arauco
# 219                                            NaN
# 220                                            NaN
# 221                                         Arauco
# 222                                         Arauco
# 223                                         Arauco
# 224                                         Arauco
# 225                                         Arauco
# 226                                         Arauco
# 227                                         Arauco
# 228                                         Arauco
# 229                                         Arauco
# 230                                            NaN
# 231                                            NaN
# 232                                            NaN
# 233                                            NaN
# 234                                            NaN
# 235                                            NaN
# 236                                            NaN
# 237                                            NaN
# 238                                            NaN
# 239                                       Nagalhue
# 240                                         Arauco
# 241                                            NaN
# 242                                            NaN
# 243                                            NaN
# 244                                            NaN
# 245                                         Arauco
# 246                                            NaN
# 247  Argentina, Río Negro, Cordillera de Los Andes
# 248                                         Arauco
# 249                                         Arauco
# 250                                            NaN
# 251                                            NaN
# 252                                            NaN
# 253                                            NaN

# %% [markdown]
# ## Verification

# %%
import glob
from collections import defaultdict


def verification(csv):
    
    """
    Function to return a csv file with a condition column indicating if any files are missing in the inventory, 
    and the different paths for each entity
    
    :csv: String, file path csv
    :return: None
    """
    
    df = pd.read_csv(csv, delimiter=",")
    
    #Creations columns
    df["Condition"] = ""
    df["files"] = ""
    
    #
    dict_files = defaultdict(list)
    dict_id = df.set_index('Id').to_dict()['Nb']
    
    #Verify condition
    for items in glob.glob("data/JPG/*.jpg"):
        #Exception for 1677 (no for 1643 which doesn't exist in repo)
        if items == "data/JPG/1677_b.jpg" or items == "data/JPG/1677_a.jpg":
            id = int(items[9:13])
            dict_files[id].append(items)
            df.loc[df['Id'] == id, 'Condition'] = "Missing files"
        else:
            if int(items[9:12]) in dict_id:
                id = int(items[9:12])
                dict_files[id].append(items)
                if len(dict_files[id]) == dict_id[id]:
                    df.loc[df['Id'] == id, 'Condition'] = "Verify !"
                elif len(dict_files[id]) == (dict_id[id] * 2):
                    df.loc[df['Id'] == id, 'Condition'] = "True"
                elif len(dict_files[id]) > dict_id[id]:
                    df.loc[df['Id'] == id, 'Condition'] = "Contains extra files"
                elif len(dict_files[id]) > 0 and len(dict_files[id]) < dict_id[id]:
                    df.loc[df['Id'] == id, 'Condition'] = "Missing files"
    
    #Loop to put all paths by id -> indexation
    for id in dict_files:
        for file in dict_files[id]:
            df.loc[df['Id'] == id, 'files'] += file
            df.loc[df['Id'] == id, 'files'] += ";"
    
    #Clean dataframe (dont work :/)
    df.replace('^$', np.nan, regex=True)
    
    #Test
    assert df['Condition'].iloc[89] == 'True', "The result should be equivalent to True"
    assert df['Condition'].iloc[118] == 'Verify !', "The result should be equivalent to 'Verify !'"
    assert len(dict_files[305]) == 4, "The result should be equivalent to 4"
    assert dict_id[195] == 1, "The result should be equivalent to 1"
    
    #Write csv #Empty cells in 'Condition' means the file don't exist
    df.to_csv(r'data/araucania_final.csv')

# %%
#run
verification('data/araucania_prepared.csv')

# %% [markdown]
# ## Files management

# %%
def make_list(column):
    """
    Function returning a list of differents type of documents in csv column
    return: set list
    """
    list_type = []
    for type in df[column]:
        list_type.append(type)
        type_set = set(list_type)
    return type_set

# %%
def list_files(column, select):
    """
    Faire une liste des chemins en fonction du type
    
    :theme: Str, type
    :return: None
    """
    df = pd.read_csv('data/araucania_final.csv', delimiter=",")
    
    list_f=[]
    ids = df.loc[df[column] == select, 'files'].tolist()
    for files in ids:
        try: #Avoids problems of empty cells
            file = files.split(';')
            list_f.append(file)
        except(AttributeError):
            pass
    return list_f

def manage_folder(theme):
    """
    Creation of directory by type
    
    :return: Warning creation
    """
    if not os.path.isdir(os.path.join(current_folder, f"data/JPG_order/{theme}")):
        os.mkdir(os.path.join(current_folder, f"data/JPG_order/{theme}"))
        return print('Creation directory : ' + theme)

def manage_files(theme):
    """
    Files management in folder in according to the type of document
    
    :return: None
    """
    try:
        manage_folder(theme)
        for files in list_files('Type', theme):
            files.remove('')
            for file in files:
                basename = file[9:]
                if os.path.exists(os.path.join(current_folder, f"data/JPG_order/{theme}/{basename}")):
                    print(basename + " : the file already exists")
                else:
                    shutil.copy(file, f"data/JPG_order/{theme}/")
    except(AttributeError):
        print(theme)
        pass
    #test
    assert os.path.isfile(os.path.join(current_folder, "data/JPG_order/Notes/311_a.jpg")) == True, "File don't exist"
    assert len(os.listdir(os.path.join(current_folder, "data/JPG_order/Notes"))) == 48, "The number of files is incorrect"

# %%
def active_manage():
    """
    Active management by theme
    
    :return: None
    """
    for theme in make_list('Type'):
        manage_files(theme)

# %%
#run
active_manage()
# Out:
# 150_b.jpg : the file already exists
# 150_a.jpg : the file already exists
# 151_1_b.jpg : the file already exists
# 151_1_a.jpg : the file already exists
# 151_2_a.jpg : the file already exists
# 151_2_b.jpg : the file already exists
# 152_b.jpg : the file already exists
# 152_a.jpg : the file already exists
# 154_a.jpg : the file already exists
# 154_b.jpg : the file already exists
# 155_b.jpg : the file already exists
# 155_a.jpg : the file already exists
# 156_b.jpg : the file already exists
# 156_a.jpg : the file already exists
# 157_b.jpg : the file already exists
# 157_a.jpg : the file already exists
# 158_b.jpg : the file already exists
# 158_a.jpg : the file already exists
# 159_b.jpg : the file already exists
# 159_a.jpg : the file already exists
# 160_a.jpg : the file already exists
# 160_b.jpg : the file already exists
# 161_a.jpg : the file already exists
# 161_b.jpg : the file already exists
# 162_b.jpg : the file already exists
# 162_a.jpg : the file already exists
# 163_a.jpg : the file already exists
# 163_b.jpg : the file already exists
# 164_b.jpg : the file already exists
# 164_a.jpg : the file already exists
# 165_b.jpg : the file already exists
# 165_a.jpg : the file already exists
# 166_a.jpg : the file already exists
# 166_b.jpg : the file already exists
# 167_b.jpg : the file already exists
# 167_a.jpg : the file already exists
# 168_b.jpg : the file already exists
# 168_a.jpg : the file already exists
# 169_b.jpg : the file already exists
# 169_a.jpg : the file already exists
# 170_b.jpg : the file already exists
# 170_a.jpg : the file already exists
# 171_a.jpg : the file already exists
# 171_b.jpg : the file already exists
# 172_b.jpg : the file already exists
# 172_a.jpg : the file already exists
# 173_1_a.jpg : the file already exists
# 173_2_b.jpg : the file already exists
# 173_2_a.jpg : the file already exists
# 173_1_b.jpg : the file already exists
# 175_b.jpg : the file already exists
# 175_a.jpg : the file already exists
# 176_a.jpg : the file already exists
# 176_b.jpg : the file already exists
# 177_a.jpg : the file already exists
# 177_2a.jpg : the file already exists
# 177_2b.jpg : the file already exists
# 177_1b.jpg : the file already exists
# 178_a.jpg : the file already exists
# 178_b.jpg : the file already exists
# 179_b.jpg : the file already exists
# 179_a.jpg : the file already exists
# 181_a.jpg : the file already exists
# 181_b.jpg : the file already exists
# 182_b.jpg : the file already exists
# 182_a.jpg : the file already exists
# 183_b.jpg : the file already exists
# 183_a.jpg : the file already exists
# 184_a.jpg : the file already exists
# 184_b.jpg : the file already exists
# 185_b.jpg : the file already exists
# 185_a.jpg : the file already exists
# 186_a.jpg : the file already exists
# 186_b.jpg : the file already exists
# 187_b.jpg : the file already exists
# 187_a.jpg : the file already exists
# 188_a.jpg : the file already exists
# 188_b.jpg : the file already exists
# 189_a.jpg : the file already exists
# 189_b.jpg : the file already exists
# 190_b.jpg : the file already exists
# 190_a.jpg : the file already exists
# 191_b.jpg : the file already exists
# 191_a.jpg : the file already exists
# 192_a.jpg : the file already exists
# 192_b.jpg : the file already exists
# 193_b.jpg : the file already exists
# 193_a.jpg : the file already exists
# 194_a.jpg : the file already exists
# 194_b.jpg : the file already exists
# 195_a.jpg : the file already exists
# 195_b.jpg : the file already exists
# 196_a.jpg : the file already exists
# 196_b.jpg : the file already exists
# 197_b.jpg : the file already exists
# 197_a.jpg : the file already exists
# 198_2_b.jpg : the file already exists
# 198_1_a.jpg : the file already exists
# 198_1_b.jpg : the file already exists
# 198_2_a.jpg : the file already exists
# 199_b.jpg : the file already exists
# 199_a.jpg : the file already exists
# 200_b.jpg : the file already exists
# 200_a.jpg : the file already exists
# 201_a.jpg : the file already exists
# 201_b.jpg : the file already exists
# 202_b.jpg : the file already exists
# 202_a.jpg : the file already exists
# 203_a.jpg : the file already exists
# 204_b.jpg : the file already exists
# 204_a.jpg : the file already exists
# 205_b.jpg : the file already exists
# 205_a.jpg : the file already exists
# 206_a.jpg : the file already exists
# 206_b.jpg : the file already exists
# 207_b.jpg : the file already exists
# 207_a.jpg : the file already exists
# 208_a.jpg : the file already exists
# 208_b.jpg : the file already exists
# 209_b.jpg : the file already exists
# 209_a.jpg : the file already exists
# 210_b.jpg : the file already exists
# 210_a.jpg : the file already exists
# 211_a.jpg : the file already exists
# 211_b.jpg : the file already exists
# 212_a.jpg : the file already exists
# 212_b.jpg : the file already exists
# 213_b.jpg : the file already exists
# 213_a.jpg : the file already exists
# 214_1_a.jpg : the file already exists
# 214_2_a.jpg : the file already exists
# 214_1_b.jpg : the file already exists
# 214_2_b.jpg : the file already exists
# 215_1_a.jpg : the file already exists
# 215_2_a.jpg : the file already exists
# 215_1_b.jpg : the file already exists
# 215_2_b.jpg : the file already exists
# 216_b.jpg : the file already exists
# 216_a.jpg : the file already exists
# 217_a.jpg : the file already exists
# 217_b.jpg : the file already exists
# 218_a.jpg : the file already exists
# 218_b.jpg : the file already exists
# 219_b.jpg : the file already exists
# 219_a.jpg : the file already exists
# 220_a.jpg : the file already exists
# 220_b.jpg : the file already exists
# 221_a.jpg : the file already exists
# 221_b.jpg : the file already exists
# 222_b.jpg : the file already exists
# 222_a.jpg : the file already exists
# 223_b.jpg : the file already exists
# 223_a.jpg : the file already exists
# 224_a.jpg : the file already exists
# 224_b.jpg : the file already exists
# 225_b.jpg : the file already exists
# 225_a.jpg : the file already exists
# 226_a.jpg : the file already exists
# 226_b.jpg : the file already exists
# 227_b.jpg : the file already exists
# 227_a.jpg : the file already exists
# 228_a.jpg : the file already exists
# 228_a_.jpg : the file already exists
# 228_b.jpg : the file already exists
# 229_a.jpg : the file already exists
# 229_b.jpg : the file already exists
# 230_a_.jpg : the file already exists
# 230_b.jpg : the file already exists
# 231_b.jpg : the file already exists
# 231_a.jpg : the file already exists
# 232_b.jpg : the file already exists
# 232_a.jpg : the file already exists
# 233_a.jpg : the file already exists
# 233_b.jpg : the file already exists
# 234_b.jpg : the file already exists
# 234_a.jpg : the file already exists
# 235_b.jpg : the file already exists
# 235_a.jpg : the file already exists
# 236_b.jpg : the file already exists
# 236_a.jpg : the file already exists
# 237_b.jpg : the file already exists
# 237_a.jpg : the file already exists
# 238_a.jpg : the file already exists
# 238_b.jpg : the file already exists
# 239_a.jpg : the file already exists
# 239_b.jpg : the file already exists
# 240_a.jpg : the file already exists
# 240_b.jpg : the file already exists
# 241_a.jpg : the file already exists
# 241_b.jpg : the file already exists
# 242_b.jpg : the file already exists
# 242_a.jpg : the file already exists
# 243_b.jpg : the file already exists
# 243_a.jpg : the file already exists
# 244_b.jpg : the file already exists
# 244_a.jpg : the file already exists
# 245_b.jpg : the file already exists
# 245_a.jpg : the file already exists
# 246_a.jpg : the file already exists
# 246_b.jpg : the file already exists
# 247_a.jpg : the file already exists
# 248_b.jpg : the file already exists
# 248_a.jpg : the file already exists
# 249_a.jpg : the file already exists
# 249_b.jpg : the file already exists
# 250_a.jpg : the file already exists
# 250_b.jpg : the file already exists
# 251_b.jpg : the file already exists
# 251_a.jpg : the file already exists
# 252_b.jpg : the file already exists
# 252_a.jpg : the file already exists
# 253_a.jpg : the file already exists
# 253_b.jpg : the file already exists
# 254_b.jpg : the file already exists
# 254_a.jpg : the file already exists
# 255_a.jpg : the file already exists
# 255_b.jpg : the file already exists
# 256_b.jpg : the file already exists
# 256_a.jpg : the file already exists
# 257_a.jpg : the file already exists
# 257_a_.jpg : the file already exists
# 257_b.jpg : the file already exists
# 258_a.jpg : the file already exists
# 258_b.jpg : the file already exists
# 259_b.jpg : the file already exists
# 259_a.jpg : the file already exists
# 260_b.jpg : the file already exists
# 260_a.jpg : the file already exists
# 261_a.jpg : the file already exists
# 261_b.jpg : the file already exists
# 262_a.jpg : the file already exists
# 262_b.jpg : the file already exists
# 264_a.jpg : the file already exists
# 264_b.jpg : the file already exists
# 265_a.jpg : the file already exists
# 265_b.jpg : the file already exists
# 266_a.jpg : the file already exists
# 266_b.jpg : the file already exists
# 267_a.jpg : the file already exists
# 267_b.jpg : the file already exists
# 268_1_b.jpg : the file already exists
# 268_1_a.jpg : the file already exists
# 269_b.jpg : the file already exists
# 269_a.jpg : the file already exists
# 270_b.jpg : the file already exists
# 270_a.jpg : the file already exists
# 271_b.jpg : the file already exists
# 271_a.jpg : the file already exists
# 272_a.jpg : the file already exists
# 272_b.jpg : the file already exists
# 273_b.jpg : the file already exists
# 273_a.jpg : the file already exists
# 274_a.jpg : the file already exists
# 274_b.jpg : the file already exists
# 275_b.jpg : the file already exists
# 275_a.jpg : the file already exists
# 276_b.jpg : the file already exists
# 276_a.jpg : the file already exists
# 277_b.jpg : the file already exists
# 277_a.jpg : the file already exists
# 278_b.jpg : the file already exists
# 279_b.jpg : the file already exists
# 279_a.jpg : the file already exists
# 280_a.jpg : the file already exists
# 280_b.jpg : the file already exists
# 281_a.jpg : the file already exists
# 281_b.jpg : the file already exists
# 282_b.jpg : the file already exists
# 282_a.jpg : the file already exists
# 283_b.jpg : the file already exists
# 283_a.jpg : the file already exists
# 284_a.jpg : the file already exists
# 284_b.jpg : the file already exists
# 285_b.jpg : the file already exists
# 285_a.jpg : the file already exists
# 286_b.jpg : the file already exists
# 286_a.jpg : the file already exists
# 287_a.jpg : the file already exists
# 287_b.jpg : the file already exists
# 288_b.jpg : the file already exists
# 288_a.jpg : the file already exists
# 289_a.jpg : the file already exists
# 289_b.jpg : the file already exists
# 290_a.jpg : the file already exists
# 290_b.jpg : the file already exists
# 291_b.jpg : the file already exists
# 291_a.jpg : the file already exists
# 292_a.jpg : the file already exists
# 292_b.jpg : the file already exists
# 293_a.jpg : the file already exists
# 293_b.jpg : the file already exists
# 294_a.jpg : the file already exists
# 294_b.jpg : the file already exists
# 295_a.jpg : the file already exists
# 295_b.jpg : the file already exists
# 296_a.jpg : the file already exists
# 296_b.jpg : the file already exists
# 297_a.jpg : the file already exists
# 297_b.jpg : the file already exists
# 298_a.jpg : the file already exists
# 298_b.jpg : the file already exists
# 299_a.jpg : the file already exists
# 299_b.jpg : the file already exists
# 300_a.jpg : the file already exists
# 300_b.jpg : the file already exists
# 301_a.jpg : the file already exists
# 301_b.jpg : the file already exists
# 304_2_b.jpg : the file already exists
# 304_1_a.jpg : the file already exists
# 304_1_b.jpg : the file already exists
# 304_2_a.jpg : the file already exists
# 305_2_b.jpg : the file already exists
# 305_1_a.jpg : the file already exists
# 305_2_a.jpg : the file already exists
# 305_a.jpg : the file already exists
# 313_a.jpg : the file already exists
# 313_b.jpg : the file already exists
# 314_b.jpg : the file already exists
# 314_a.jpg : the file already exists
# 315_a.jpg : the file already exists
# 315_a_.jpg : the file already exists
# 316_a.jpg : the file already exists
# 316_b.jpg : the file already exists
# 317_a.jpg : the file already exists
# 317_b.jpg : the file already exists
# 322_b.jpg : the file already exists
# 322_a.jpg : the file already exists
# 323_b.jpg : the file already exists
# 323_a.jpg : the file already exists
# 325_b.jpg : the file already exists
# 325_a.jpg : the file already exists
# 326-b.jpg : the file already exists
# 326_a.jpg : the file already exists
# 327_a.jpg : the file already exists
# 327_b.jpg : the file already exists
# 328_b.jpg : the file already exists
# 328_a.jpg : the file already exists
# 329_b.jpg : the file already exists
# 329_a.jpg : the file already exists
# 331_a.jpg : the file already exists
# 331_b.jpg : the file already exists
# 332_b.jpg : the file already exists
# 332_a.jpg : the file already exists
# 335_a.jpg : the file already exists
# 335_b.jpg : the file already exists
# 337_b.jpg : the file already exists
# 337_a.jpg : the file already exists
# 339_b.jpg : the file already exists
# 339_a.jpg : the file already exists
# 340_a.jpg : the file already exists
# 340_b.jpg : the file already exists
# 341_a.jpg : the file already exists
# 341_b.jpg : the file already exists
# 345_b.jpg : the file already exists
# 345_a.jpg : the file already exists
# 346_a.jpg : the file already exists
# 346_b.jpg : the file already exists
# 347_b.jpg : the file already exists
# 347_a.jpg : the file already exists
# 349_b.jpg : the file already exists
# 349_a.jpg : the file already exists
# 350_a.jpg : the file already exists
# 350_b.jpg : the file already exists
# 351_a.jpg : the file already exists
# 351_b.jpg : the file already exists
# 352_a.jpg : the file already exists
# 352_b.jpg : the file already exists
# 353_a.jpg : the file already exists
# 353_b.jpg : the file already exists
# 354_b.jpg : the file already exists
# 354_a.jpg : the file already exists
# 355_b.jpg : the file already exists
# 355_a.jpg : the file already exists
# 356_a.jpg : the file already exists
# 356_b.jpg : the file already exists
# 357_a.jpg : the file already exists
# 357_b.jpg : the file already exists
# 358_b.jpg : the file already exists
# 358_a.jpg : the file already exists
# 359_b.jpg : the file already exists
# 359_a.jpg : the file already exists
# 360_a.jpg : the file already exists
# 360_b.jpg : the file already exists
# 361_b.jpg : the file already exists
# 361_a.jpg : the file already exists
# 362_b.jpg : the file already exists
# 362_a.jpg : the file already exists
# 363_a.jpg : the file already exists
# 363_b.jpg : the file already exists
# 364_b.jpg : the file already exists
# 364_a.jpg : the file already exists
# 365_a.jpg : the file already exists
# 365_b.jpg : the file already exists
# 366_b.jpg : the file already exists
# 366_a.jpg : the file already exists
# 367_b.jpg : the file already exists
# 367_a.jpg : the file already exists
# 368_a.jpg : the file already exists
# 368_b.jpg : the file already exists
# 369_b.jpg : the file already exists
# 369_a.jpg : the file already exists
# 370_b.jpg : the file already exists
# 370_a.jpg : the file already exists
# 371_a.jpg : the file already exists
# 371_b.jpg : the file already exists
# 372_a.jpg : the file already exists
# 372_b.jpg : the file already exists
# 373_b.jpg : the file already exists
# 373_a.jpg : the file already exists
# 374_a.jpg : the file already exists
# 374_b.jpg : the file already exists
# 380_a.jpg : the file already exists
# 380_b.jpg : the file already exists
# 381_b.jpg : the file already exists
# 381_a.jpg : the file already exists
# 382_b.jpg : the file already exists
# 382_a.jpg : the file already exists
# 383_b.jpg : the file already exists
# 383_a.jpg : the file already exists
# 384_b.jpg : the file already exists
# 384_a.jpg : the file already exists
# 385_a.jpg : the file already exists
# 385_b.jpg : the file already exists
# 386_b.jpg : the file already exists
# 386_a.jpg : the file already exists
# 387_b.jpg : the file already exists
# 387_a.jpg : the file already exists
# 388_b.jpg : the file already exists
# 388_a.jpg : the file already exists
# 390_b.jpg : the file already exists
# 390_a.jpg : the file already exists
# 393_a.jpg : the file already exists
# 393_b.jpg : the file already exists
# 1677_b.jpg : the file already exists
# 1677_a.jpg : the file already exists
# 395_14_a.jpg : the file already exists
# 395_10_b.jpg : the file already exists
# 395_3_b.jpg : the file already exists
# 395_2_b.jpg : the file already exists
# 395_22_a.jpg : the file already exists
# 395_5_b.jpg : the file already exists
# 395_7_a.jpg : the file already exists
# 395_19_a.jpg : the file already exists
# 395_21_b.jpg : the file already exists
# 395_5_a.jpg : the file already exists
# 395_8_b.jpg : the file already exists
# 395_3_a.jpg : the file already exists
# 395_4_a.jpg : the file already exists
# 395_2_a.jpg : the file already exists
# 395_12_a.jpg : the file already exists
# 395_15_b.jpg : the file already exists
# 395_6_a.jpg : the file already exists
# 395_1_b.jpg : the file already exists
# 395_17_b.jpg : the file already exists
# 395_19_b.jpg : the file already exists
# 395_6_b.jpg : the file already exists
# 395_18_a.jpg : the file already exists
# 395_1_a.jpg : the file already exists
# 395_7_b.jpg : the file already exists
# 395_4_b.jpg : the file already exists
# 395_16_b.jpg : the file already exists
# 395_9_a.jpg : the file already exists
# 395_13_b.jpg : the file already exists
# 395_15_a.jpg : the file already exists
# 395_11_a.jpg : the file already exists
# 395_9_b.jpg : the file already exists
# 395_20_b.jpg : the file already exists
# 395_14_b.jpg : the file already exists
# 395_11_b.jpg : the file already exists
# 395_8_a.jpg : the file already exists
# 395_13_a.jpg : the file already exists
# 395_10_a.jpg : the file already exists
# 395_18_b.jpg : the file already exists
# 395_22_b.jpg : the file already exists
# 395_12_b.jpg : the file already exists
# 395_16_a.jpg : the file already exists
# 395_17_a.jpg : the file already exists
# 395_21_a.jpg : the file already exists
# 395_20_a.jpg : the file already exists
# 397_2_a.jpg : the file already exists
# 397_6_a.jpg : the file already exists
# 397_2_b.jpg : the file already exists
# 397_1_a.jpg : the file already exists
# 397_4_b.jpg : the file already exists
# 397_4_a.jpg : the file already exists
# 397_5_b.jpg : the file already exists
# 397_3_a.jpg : the file already exists
# 397_3_b.jpg : the file already exists
# 397_1_b.jpg : the file already exists
# 397_5_A.jpg : the file already exists
# 302_a.jpg : the file already exists
# 302_b.jpg : the file already exists
# 303_b.jpg : the file already exists
# 303_a.jpg : the file already exists
# 306_b.jpg : the file already exists
# 306_a.jpg : the file already exists
# 307_a.jpg : the file already exists
# 307_b.jpg : the file already exists
# 308_a.jpg : the file already exists
# 308_b.jpg : the file already exists
# 309_a.jpg : the file already exists
# 309_b.jpg : the file already exists
# 310_a.jpg : the file already exists
# 310_b.jpg : the file already exists
# 311_a.jpg : the file already exists
# 311_b.jpg : the file already exists
# 318_b.jpg : the file already exists
# 318_a.jpg : the file already exists
# 319_b.jpg : the file already exists
# 319_a.jpg : the file already exists
# 320_b.jpg : the file already exists
# 320_a.jpg : the file already exists
# 321_b.jpg : the file already exists
# 321_a.jpg : the file already exists
# 324_a.jpg : the file already exists
# 324_b.jpg : the file already exists
# 330_a.jpg : the file already exists
# 330_b.jpg : the file already exists
# 333_b.jpg : the file already exists
# 333_a.jpg : the file already exists
# 334_a.jpg : the file already exists
# 334_b.jpg : the file already exists
# 336_a.jpg : the file already exists
# 336_b.jpg : the file already exists
# 338_a.jpg : the file already exists
# 338_b.jpg : the file already exists
# 342_a.jpg : the file already exists
# 342_b.jpg : the file already exists
# 343_2_a.jpg : the file already exists
# 343_2_b.jpg : the file already exists
# 343_1_b.jpg : the file already exists
# 343_1_a.jpg : the file already exists
# 344_b.jpg : the file already exists
# 344_a.jpg : the file already exists
# 348_a.jpg : the file already exists
# 348_b.jpg : the file already exists
# 389_b.jpg : the file already exists
# 389_a.jpg : the file already exists
# 375_a.jpg : the file already exists
# 375_b.jpg : the file already exists
# 376_a.jpg : the file already exists
# 376_b.jpg : the file already exists
# 377_a.jpg : the file already exists
# 377_b.jpg : the file already exists
# 378_a.jpg : the file already exists
# 378_b.jpg : the file already exists
# 379_b.jpg : the file already exists
# 379_a.jpg : the file already exists
# 398.jpg : the file already exists
# 399.jpg : the file already exists
# 887_2_2.jpg : the file already exists
# 887_11_a.jpg : the file already exists
# 887_34.jpg : the file already exists
# 887_59.jpg : the file already exists
# 887_2_3.jpg : the file already exists
# 887_2_8.jpg : the file already exists
# 887_1_a.jpg : the file already exists
# 887_6_a.jpg : the file already exists
# 887_55.jpg : the file already exists
# 887_28.jpg : the file already exists
# 887_26.jpg : the file already exists
# 887_9_a.jpg : the file already exists
# 887_7_b.jpg : the file already exists
# 887_15.jpg : the file already exists
# 887_4_b.jpg : the file already exists
# 887_41.jpg : the file already exists
# 887_38.jpg : the file already exists
# 887_2_17.jpg : the file already exists
# 887_2_4.jpg : the file already exists
# 887_5_a.jpg : the file already exists
# 887_2_6.jpg : the file already exists
# 887_43.jpg : the file already exists
# 887_33.jpg : the file already exists
# 887_2_11.jpg : the file already exists
# 887_29.jpg : the file already exists
# 887_32.jpg : the file already exists
# 887_3_b.jpg : the file already exists
# 887_16.jpg : the file already exists
# 887_2_1.jpg : the file already exists
# 887_42.jpg : the file already exists
# 887_10_b.jpg : the file already exists
# 887_35.jpg : the file already exists
# 887_2_13.jpg : the file already exists
# 887_39.jpg : the file already exists
# 887_45.jpg : the file already exists
# 887_21.jpg : the file already exists
# 887_61.jpg : the file already exists
# 887_57.jpg : the file already exists
# 887_24.jpg : the file already exists
# 887_40.jpg : the file already exists
# 887_52.jpg : the file already exists
# 887_8_a.jpg : the file already exists
# 887_56.jpg : the file already exists
# 887_2_16.jpg : the file already exists
# 887_2_18.jpg : the file already exists
# 887_44.jpg : the file already exists
# 887_14.jpg : the file already exists
# 887_58.jpg : the file already exists
# 887_4_a.jpg : the file already exists
# 887_37.jpg : the file already exists
# 887_31.jpg : the file already exists
# 887_2_b.jpg : the file already exists
# 887_2_15.jpg : the file already exists
# 887_49.jpg : the file already exists
# 887_2_20.jpg : the file already exists
# 887_6_b.jpg : the file already exists
# 887_1_b.jpg : the file already exists
# 887_30.jpg : the file already exists
# 887_9_b.jpg : the file already exists
# 887_23.jpg : the file already exists
# 887_5_b.jpg : the file already exists
# 887_36.jpg : the file already exists
# 887_12.jpg : the file already exists
# 887_53.jpg : the file already exists
# 887_50.jpg : the file already exists
# 887_2_9.jpg : the file already exists
# 887_17.jpg : the file already exists
# 887_2_7.jpg : the file already exists
# 887_7_a.jpg : the file already exists
# 887_22.jpg : the file already exists
# 887_tapa_a.jpg : the file already exists
# 887_11_b.jpg : the file already exists
# 887_47.jpg : the file already exists
# 887_13.jpg : the file already exists
# 887_3_atif.jpg : the file already exists
# 887_tapa_b.jpg : the file already exists
# 887_25.jpg : the file already exists
# 887_2_5.jpg : the file already exists
# 887_2_10.jpg : the file already exists
# 887_20.jpg : the file already exists
# 887_8_b.jpg : the file already exists
# 887_2_a.jpg : the file already exists
# 887_54.jpg : the file already exists
# 887_51.jpg : the file already exists
# 887_2_12.jpg : the file already exists
# 887_60.jpg : the file already exists
# 887_27.jpg : the file already exists
# 887_48.jpg : the file already exists
# 887_46.jpg : the file already exists
# 887_2_19.jpg : the file already exists
# 887_18.jpg : the file already exists
# 887_19.jpg : the file already exists
# 887_10_a.jpg : the file already exists
# 887_2_14.jpg : the file already exists
# 888_30.jpg : the file already exists
# 888_23.jpg : the file already exists
# 888_61.jpg : the file already exists
# 888_48.jpg : the file already exists
# 888_58.jpg : the file already exists
# 888_50.jpg : the file already exists
# 888_5.jpg : the file already exists
# 888_88.jpg : the file already exists
# 888_104.jpg : the file already exists
# 888_84.jpg : the file already exists
# 888_79.jpg : the file already exists
# 888_103.jpg : the file already exists
# 888_64.jpg : the file already exists
# 888_41.jpg : the file already exists
# 888_7.jpg : the file already exists
# 888_40.jpg : the file already exists
# 888_54.jpg : the file already exists
# 888_47.jpg : the file already exists
# 888_102.jpg : the file already exists
# 888_2.jpg : the file already exists
# 888_55.jpg : the file already exists
# 888_105.jpg : the file already exists
# 888_71.jpg : the file already exists
# 888_89.jpg : the file already exists
# 888_96.jpg : the file already exists
# 888_18.jpg : the file already exists
# 888_27.jpg : the file already exists
# 888_14.jpg : the file already exists
# 888_32.jpg : the file already exists
# 888_9.jpg : the file already exists
# 888_76.jpg : the file already exists
# 888_63.jpg : the file already exists
# 888_92.jpg : the file already exists
# 888_106.jpg : the file already exists
# 888_39.jpg : the file already exists
# 888_107.jpg : the file already exists
# 888_86.jpg : the file already exists
# 888_108.jpg : the file already exists
# 888_98.jpg : the file already exists
# 888_37.jpg : the file already exists
# 888_6.jpg : the file already exists
# 888_tapa.jpg : the file already exists
# 888_26.jpg : the file already exists
# 888_35.jpg : the file already exists
# 888_100.jpg : the file already exists
# 888_91.jpg : the file already exists
# 888_75.jpg : the file already exists
# 888_82.jpg : the file already exists
# 888_46.jpg : the file already exists
# 888_33.jpg : the file already exists
# 888_20.jpg : the file already exists
# 888_15.jpg : the file already exists
# 888_97.jpg : the file already exists
# 888_44.jpg : the file already exists
# 888_77.jpg : the file already exists
# 888_24_.jpg : the file already exists
# 888_53.jpg : the file already exists
# 888_43.jpg : the file already exists
# 888_49.jpg : the file already exists
# 888_19.jpg : the file already exists
# 888_13.jpg : the file already exists
# 888_28.jpg : the file already exists
# 888_tapa2.jpg : the file already exists
# 888_66.jpg : the file already exists
# 888_11.jpg : the file already exists
# 888_36.jpg : the file already exists
# 888_38.jpg : the file already exists
# 888_78.jpg : the file already exists
# 888_60.jpg : the file already exists
# 888_94.jpg : the file already exists
# 888_34.jpg : the file already exists
# 888_51.jpg : the file already exists
# 888_81.jpg : the file already exists
# 888_90.jpg : the file already exists
# 888_17.jpg : the file already exists
# 888_95.jpg : the file already exists
# 888_69.jpg : the file already exists
# 888_45.jpg : the file already exists
# 888_10.jpg : the file already exists
# 888_16.jpg : the file already exists
# 888_22.jpg : the file already exists
# 888_93.jpg : the file already exists
# 888_65.jpg : the file already exists
# 888_3.jpg : the file already exists
# 888_1.jpg : the file already exists
# 888_8.jpg : the file already exists
# 888_85.jpg : the file already exists
# 888_83.jpg : the file already exists
# 888_29.jpg : the file already exists
# 888_99.jpg : the file already exists
# 888_56.jpg : the file already exists
# 888_24.jpg : the file already exists
# 888_31.jpg : the file already exists
# 888_70.jpg : the file already exists
# 888_52.jpg : the file already exists
# 888_74.jpg : the file already exists
# 888_21.jpg : the file already exists
# 888_80.jpg : the file already exists
# 888_59.jpg : the file already exists
# 888_73.jpg : the file already exists
# 888_67.jpg : the file already exists
# 888_57.jpg : the file already exists
# 888_72.jpg : the file already exists
# 888_12.jpg : the file already exists
# 888_62.jpg : the file already exists
# 888_87.jpg : the file already exists
# 888_42.jpg : the file already exists
# 888_25.jpg : the file already exists
# 888_101.jpg : the file already exists
# 888_4.jpg : the file already exists
# 180_a.jpg : the file already exists
# 180_b.jpg : the file already exists
# 312_B.jpg : the file already exists
# 312_a.jpg : the file already exists
# 153_b.jpg : the file already exists
# 174_a.jpg : the file already exists
# 174_b.jpg : the file already exists
# 263_b.jpg : the file already exists
# 263_a.jpg : the file already exists
# 392_a.jpg : the file already exists
# 392_b.jpg : the file already exists
# 394_b.jpg : the file already exists
# 394_a.jpg : the file already exists
# 396_3_b.jpg : the file already exists
# 396_1_a.jpg : the file already exists
# 396_2_a.jpg : the file already exists
# 396_3_a.jpg : the file already exists
# 396_2_b.jpg : the file already exists
# 396_1_b.jpg : the file already exists

# %% [markdown]
# ## Select files (Model)

# %%
def list_author():
    """
    Select documents by order
    
    :return: List \(set)\
    """
    
    df = pd.read_csv('data/araucania_final.csv', delimiter=",")
    
    list_author = []
    for type in df['Author']:
        list_author.append(type)
    author_set = list(set(list_author))
        
    assert "Barbosa, Mauricio" in list_author, "Missing authors, Barbosa, Mauricio !"
    assert len(author_set) == 46, "Missing authors !"
    return author_set

def model_files(name):
    
    """
    Clean list by author and create directory and copy with random selection.
    
    :name: Str -> name of author selected
    :return: True -> to may incrementation of parent function
    """
    #Cleaning
    list_choice = []
    for files in list_files('Author', name):
        files.remove('')
        for file in files:
            list_choice.append(file)
    #Selection       
    if len(list_choice) > 15 and len(list_choice) < 21:
        os.mkdir(os.path.join(current_folder, f"data/JPG_order/data_model/{name}"))
        try:
            for filename in list_choice:
                shutil.copy(file_name, f"data/JPG_order/data_model/{name}/")
            return True
        #Missing files in database
        except(FileNotFoundError):
            return print(f"{name} is missing")
            pass
    if len(list_choice) > 20:
        os.mkdir(os.path.join(current_folder, f"data/JPG_order/data_model/{name}"))
        list_name = random.choices(list_choice, k=20)
        try:
            for filename in list_name:
                shutil.copy(filename, f"data/JPG_order/data_model/{name}/")
        except(FileNotFoundError):
            return print(f"{name} is missing")
        return True
    
def execute_model():
    """
    Execution of function model by random author selection
    
    :return: List -> to do verification 
    """
    manage_folder("data_model")
    list_name = np.array(list_author())
    i = 0
    liste = []
    while i < 7:
        name = random.choice(list_name)
        liste.append(name)
        if not name == 'nan' and not os.path.isdir(os.path.join(current_folder, f"data/JPG_order/data_model/{name}")):
            model_files(name)
            if True:
                i += 1
    return liste

# try except FileNotFoundError  parce qu'il manque des fichiers dans la bdd

# %%
# Run
execute_model()

## BUG : Problem of return on the random. It seems that the selection of elements brings memory difficulties
# Out:
# ['García Videla, Daniel',
#  'Ramírez, Eleuterio',
#  'Cordovez, Aniceto',
#  'Capitán Gacitúa',
#  'Díaz, José Del Carmen',
#  'Williams, Juan',
#  'García, Manuel']

# %%
#testing
list_choice = []
for files in list_files('Author', "García, Manuel"):
    files.remove('')
    for file in files:
        list_choice.append(file)
name = "García, Manuel"
if len(list_choice) > 15 and len(list_choice) < 21:
    os.mkdir(os.path.join(current_folder, f"data/JPG_order/data_model/{name}"))
    for filename in list_choice:
        shutil.copy(file_name, f"data/JPG_order/data_model/{name}/")
if len(list_choice) > 20:
    os.mkdir(os.path.join(current_folder, f"data/JPG_order/data_model/{name}"))
    list_name = random.choices(list_choice, k=20)
    for filename in list_name:
        shutil.copy(filename, f"data/JPG_order/data_model/{name}/")
