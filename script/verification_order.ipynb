# %% [markdown]
# # Verification

# %% [markdown]
# Small program to check the existence of files referenced in the directory and sort it according to the type of documents
# Bonus : hand count

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/rayondemiel/Bureau/Stage Araucanía/data_preparation/.env/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /home/rayondemiel/Bureau/Stage Araucanía/data_preparation/.env/lib/python3.8/site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/rayondemiel/Bureau/Stage Araucanía/data_preparation/.env/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/rayondemiel/Bureau/Stage Araucanía/data_preparation/.env/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/rayondemiel/Bureau/Stage Araucanía/data_preparation/.env/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ## Check structures

# %%
import re
import pandas as pd

df = pd.read_csv('data/araucania_prepared.csv', delimiter=";")

print(df)
# Out:
#        Id               Type  \
# 0     150            Letters
# 1     151            Letters
# 2     152            Letters
# 3     153             Others
# 4     154            Letters
# ..    ...                ...
# 249   399                Map
# 250   887  Archives (series)
# 251   888  Archives (series)
# 252  1643               Book
# 253  1677            Letters
#
#                                                  Title  \
# 0    Carta del 08 de noviembre de 1859 de Cornelio ...
# 1    Carta del 13 de noviembre de 1859 de Cornelio ...
# 2    Carta del 13 de noviembre de 1859 de Cornelio ...
# 3    Relación de los pertrechos de guerra que se ha...
# 4    Carta del 15 de noviembre de 1859 de José Anto...
# ..                                                 ...
# 249  Mapa de 60x89 cms. de la Región de Arauco, mos...
# 250  Serie de documentos que dan cuenta de los serv...
# 251  Serie de documentos oficiales firmados por Bel...
# 252  Libro copiador de correspondencia del general ...
# 253  Carta del 27 de agosto de 1877 de Cornelio Saa...
#
#                         Author Author2         Date  \
# 0           Saavedra, Cornelio     NaN   1859/11/08
# 1           Saavedra, Cornelio     NaN   1859/11/13
# 2           Saavedra, Cornelio     NaN   1859/11/13
# 3           Valdivieso, Samuel     NaN   1859/11/13
# 4        Quezada, José Antonio     NaN   1859/11/15
# ..                         ...     ...          ...
# 249                        NaN     NaN  [Siglo XIX]
# 250                        NaN     NaN    1862-1909
# 251                        NaN     NaN         1877
# 252  Urrutia Venegas, Gregorio     NaN   1866/05/04
# 253         Saavedra, Cornelio     NaN   1877/08/27
#
#                                 Location   Nb                     People  \
# 0                                    NaN    1          Barbosa, Mauricio
# 1         Chile;Quinta Región;Valparaíso    2          Barbosa, Mauricio
# 2         Chile;Quinta Región;Valparaíso    1          Barbosa, Mauricio
# 3         Chile;Quinta Región;Valparaíso    1                        NaN
# 4             Chile;Octava Región;Arauco    1          Barbosa, Mauricio
# ..                                   ...  ...                        ...
# 249                                  NaN    1                        NaN
# 250                                  NaN   46                        NaN
# 251                                  NaN   54                        NaN
# 252             Chile;Octava Región;Lota  600                        NaN
# 253  Chile;Región Metropolitana;Santiago    1  Urrutia Venegas, Gregorio
#
#         Geo
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 249  Arauco
# 250     NaN
# 251     NaN
# 252     NaN
# 253     NaN
#
# [254 rows x 10 columns]

# %% [markdown]
# ## Program

# %%
import re, os
import pandas as pd

df = pd.read_csv('data/araucania_prepared.csv', delimiter=";")

complete = re.compile("(_|\d|[tapb])+")

#List type
liste_type = []
for type in df['Type']:
    liste_type.append(type)
    type_set = set(liste_type)
    
#
for id in df['Id']:
    path_files = f"data/jpg/{id}{complete}.jpg"
    print(path_files)

#df.to_csv(r'data/araucania_final.csv')
# Out:
# data/jpg/150re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/151re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/152re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/153re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/154re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/155re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/156re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/157re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/158re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/159re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/160re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/161re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/162re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/163re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/164re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/165re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/166re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/167re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/168re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/169re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/170re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/171re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/172re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/173re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/174re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/175re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/176re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/177re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/178re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/179re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/180re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/181re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/182re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/183re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/184re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/185re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/186re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/187re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/188re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/189re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/190re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/191re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/192re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/193re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/194re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/195re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/196re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/197re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/198re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/199re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/200re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/201re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/202re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/203re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/204re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/205re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/206re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/207re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/208re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/209re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/210re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/211re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/212re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/213re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/214re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/215re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/216re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/217re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/218re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/219re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/220re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/221re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/222re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/223re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/224re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/225re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/226re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/227re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/228re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/229re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/230re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/231re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/232re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/233re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/234re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/235re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/236re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/237re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/238re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/239re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/240re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/241re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/242re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/243re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/244re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/245re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/246re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/247re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/248re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/249re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/250re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/251re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/252re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/253re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/254re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/255re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/256re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/257re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/258re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/259re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/260re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/261re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/262re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/263re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/264re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/265re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/266re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/267re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/268re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/269re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/270re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/271re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/272re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/273re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/274re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/275re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/276re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/277re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/278re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/279re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/280re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/281re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/282re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/283re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/284re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/285re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/286re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/287re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/288re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/289re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/290re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/291re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/292re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/293re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/294re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/295re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/296re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/297re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/298re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/299re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/300re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/301re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/302re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/303re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/304re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/305re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/306re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/307re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/308re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/309re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/310re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/311re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/312re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/313re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/314re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/315re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/316re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/317re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/318re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/319re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/320re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/321re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/322re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/323re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/324re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/325re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/326re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/327re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/328re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/329re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/330re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/331re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/332re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/333re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/334re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/335re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/336re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/337re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/338re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/339re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/340re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/341re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/342re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/343re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/344re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/345re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/346re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/347re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/348re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/349re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/350re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/351re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/352re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/353re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/354re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/355re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/356re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/357re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/358re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/359re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/360re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/361re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/362re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/363re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/364re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/365re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/366re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/367re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/368re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/369re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/370re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/371re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/372re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/373re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/374re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/375re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/376re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/377re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/378re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/379re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/380re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/381re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/382re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/383re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/384re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/385re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/386re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/387re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/388re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/389re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/390re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/391re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/392re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/393re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/394re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/395re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/396re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/397re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/398re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/399re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/887re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/888re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/1643re.compile('(_|\\d|[tapb])+').jpg
# data/jpg/1677re.compile('(_|\\d|[tapb])+').jpg
